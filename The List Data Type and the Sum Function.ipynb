# %% [markdown]
# <a href="https://colab.research.google.com/github/Andrew-Makau/AI-Trader/blob/main/The%20List%20Data%20Type%20and%20the%20Sum%20Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
boba_fett_experience = 10
storm_stewart_experience = 20
experience = [boba_fett_experience,storm_stewart_experience]
total = sum(experience)
print("The total in list experience is : "+str(total))
# Out:
# The total in list experience is : 30

# %%
Ahsoka_height = 1.7
yoda_height = 0.66
r2d2 = 1.09

height = [Ahsoka_height,yoda_height,r2d2]
total_height = sum(height)
print("The total height is: "+str(total_height))
print(type(height))
# Out:
# The total height is: 3.45
# <class 'list'>

# %%
shopping_list = ["Milk", "Eggs", "Bread", "bananas"]
shopping_list.append("Apples")
shopping_list.remove("bananas")

def show_list(shopping_list):
  print("Your shopping list is:")
  for item in shopping_list:
    print(item)

def total_items(shopping_list):
  print("Total items: "+str(len(shopping_list)))

show_list(shopping_list)
total_items(shopping_list)
# Out:
# Your shopping list is:
# Milk
# Eggs
# Bread
# Apples
# Total items: 4
